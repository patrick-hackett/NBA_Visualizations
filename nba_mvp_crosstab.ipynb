# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)
pd.set_option('display.max_colwidth',None)

# %% [markdown]
# Create dataframe for player stats by season and web scrape mvp data

# %%
nba_data = pd.read_csv('nba_player_season_stats.csv')
nba_data.drop(columns=['Unnamed: 0'],inplace=True)
#nba_data.head()

# %%
request = requests.get('https://en.wikipedia.org/wiki/NBA_Most_Valuable_Player_Award')
soup = BeautifulSoup(request.content,'html.parser')
#soup.prettify()

# %% [markdown]
# Clean and format data

# %%
wiki_table = soup.find('table',{'class':'wikitable plainrowheaders sortable','summary':'Season (sortable), Player (sortable), Position (sortable), Nationality (sortable) and Team (sortable)'})

table_rows = wiki_table.find_all('tr')



mvp_lists = [row.text for row in table_rows]
season = [row.split('\n')[1] for row in mvp_lists]
player = [row.split('\n')[3] for row in mvp_lists]
position = [row.split('\n')[5] for row in mvp_lists]

mvp_df = pd.DataFrame()
mvp_df['Season'] = season
mvp_df['Player'] = player
mvp_df['Position'] = position

mvp_df = mvp_df.drop(0).reset_index(drop=True)


mvp_df['Season'] = mvp_df.Season.str.strip()

test = mvp_df.Season[0]
delimiter = test[-3]

def fix_years(season):
    season = season.split(delimiter)[1]
    if int(season) > 50:
        return (1900 + float(season))
    else:
        return (2000 + float(season))

mvp_df['Season'] = mvp_df.Season.apply(fix_years)

mvp_df['Player'] = mvp_df.Player.str.strip('*(2345678)^[h]gi ')


mvp_df.Player.iloc[25] = 'Julius Erving'
mvp_df.Player.iloc[[49,50]] = 'Steve Nash'
mvp_df.Player.iloc[15] = 'Kareem Abdul-Jabbar'
mvp_df.Player.iloc[51] = 'Dirk Nowitzki'

positions_dict = {'Center':'C','Power forward':'PF','Point guard':'PG','Shooting guard':'SG','Small forward':'SF'}

mvp_df['Position'] = mvp_df.Position.map(positions_dict)
mvp_df
# Out:
# /Users/christine/hueco_mundo/hueco_mundo/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#     Season                 Player Position
# 0   1956.0             Bob Pettit       PF
# 1   1957.0              Bob Cousy       PG
# 2   1958.0           Bill Russell        C
# 3   1959.0             Bob Pettit       PF
# 4   1960.0       Wilt Chamberlain        C
# 5   1961.0           Bill Russell        C
# 6   1962.0           Bill Russell        C
# 7   1963.0           Bill Russell        C
# 8   1964.0        Oscar Robertson       PG
# 9   1965.0           Bill Russell        C
# 10  1966.0       Wilt Chamberlain        C
# 11  1967.0       Wilt Chamberlain        C
# 12  1968.0       Wilt Chamberlain        C
# 13  1969.0             Wes Unseld        C
# 14  1970.0            Willis Reed        C
# 15  1971.0    Kareem Abdul-Jabbar        C
# 16  1972.0    Kareem Abdul-Jabbar        C
# 17  1973.0            Dave Cowens        C
# 18  1974.0    Kareem Abdul-Jabbar        C
# 19  1975.0             Bob McAdoo        C
# 20  1976.0    Kareem Abdul-Jabbar        C
# 21  1977.0    Kareem Abdul-Jabbar        C
# 22  1978.0            Bill Walton        C
# 23  1979.0           Moses Malone        C
# 24  1980.0    Kareem Abdul-Jabbar        C
# 25  1981.0          Julius Erving       SF
# 26  1982.0           Moses Malone        C
# 27  1983.0           Moses Malone        C
# 28  1984.0             Larry Bird       SF
# 29  1985.0             Larry Bird       SF
# 30  1986.0             Larry Bird       SF
# 31  1987.0          Magic Johnson       PG
# 32  1988.0         Michael Jordan       SG
# 33  1989.0          Magic Johnson       PG
# 34  1990.0          Magic Johnson       PG
# 35  1991.0         Michael Jordan       SG
# 36  1992.0         Michael Jordan       SG
# 37  1993.0        Charles Barkley       PF
# 38  1994.0        Hakeem Olajuwon        C
# 39  1995.0         David Robinson        C
# 40  1996.0         Michael Jordan       SG
# 41  1997.0            Karl Malone       PF
# 42  1998.0         Michael Jordan       SG
# 43  1999.0            Karl Malone       PF
# 44  2000.0       Shaquille O'Neal        C
# 45  2001.0          Allen Iverson       SG
# 46  2002.0             Tim Duncan       PF
# 47  2003.0             Tim Duncan       PF
# 48  2004.0          Kevin Garnett       PF
# 49  2005.0             Steve Nash       PG
# 50  2006.0             Steve Nash       PG
# 51  2007.0          Dirk Nowitzki       PF
# 52  2008.0            Kobe Bryant       SG
# 53  2009.0           LeBron James       SF
# 54  2010.0           LeBron James       SF
# 55  2011.0           Derrick Rose       PG
# 56  2012.0           LeBron James       SF
# 57  2013.0           LeBron James       SF
# 58  2014.0           Kevin Durant       SF
# 59  2015.0          Stephen Curry       PG
# 60  2016.0          Stephen Curry       PG
# 61  2017.0      Russell Westbrook       PG
# 62  2018.0           James Harden       SG
# 63  2019.0  Giannis Antetokounmpo       PF
# 64  2020.0  Giannis Antetokounmpo       PF
# 65  2021.0           Nikola Jokić        C

# %%
mvp_reference = mvp_df.iloc[:62,:]
nba_players = nba_data.iloc[:,[0,1,2]]
nba_players = nba_players[nba_players['Year']>=1956.0].reset_index(drop=True)

nba_players = nba_players.drop_duplicates()


#nba_players.info()
#nba_players.Year = nba_players.Year.fillna(1)
#nba_players.Year.value_counts()
#nba_players.Year = nba_players.Year.apply(lambda x: int(x))
nba_players.head()
# Out:
#      Year         Player Pos
# 0  1956.0   Paul Arizin*  SF
# 1  1956.0  Jesse Arnelle  PF
# 2  1956.0      Dick Atha  SG
# 3  1956.0  Jim Baechtold  SF
# 4  1956.0  Ernie Barrett  SG

# %%
def fix_pos(pos):
    a = pos.split('-')
    if len(a) > 1:
        return a[0]
    elif pos == 'F':
        return 'SF'
    elif pos == 'G':
        return 'PG'
    else:
        return pos

# %%
nba_players['Pos'] = nba_players.Pos.apply(fix_pos)
nba_players['Pos'] = nba_players.Pos.map({'F':'SF','G':'PG','C':'C','SF':'SF','PG':'PG','PF':'PF','SG':'SG'})
nba_players.Pos.value_counts()
# Out:
# PF    4098
# SG    4055
# SF    4040
# C     3998
# PG    3774
# Name: Pos, dtype: int64

# %%
nba_players['Player'] = nba_players.Player.str.strip(' *')
nba_players.reset_index(drop=True,inplace=True)

# %% [markdown]
# Identify mvp winners for each season by combining datasets

# %%
indices = []

mvp_list = list(zip(mvp_reference.Player,mvp_reference.Season))

for name,year in mvp_list:
    indices.append(nba_players.loc[(nba_players.Year == year) & (nba_players.Player == name)].index)
    
    
mvp_ix = []

for index in indices:
    mvp_ix.append(index[0])

#mvp_ix

# %%
len(mvp_ix)
# Out:
# 62

# %%
nba_players = nba_players.reset_index()
nba_players.head()

nba_players['MVP'] = nba_players['index'].apply(lambda x: 1 if x in mvp_ix else 0)
nba_players = nba_players.drop(columns=['index'])
mvp_winners = nba_players[nba_players['MVP'] == 1].head()
mvp_winners
# Out:
#        Year            Player Pos  MVP
# 65   1956.0        Bob Pettit   C    1
# 109  1957.0         Bob Cousy  PG    1
# 272  1958.0      Bill Russell   C    1
# 365  1959.0        Bob Pettit  PF    1
# 404  1960.0  Wilt Chamberlain   C    1

# %% [markdown]
# Cross-tabulate data

# %%
nba_xtab = pd.crosstab(index=nba_players.MVP,columns=nba_players.Pos,margins=True)
nba_xtab
# Out:
# Pos     C    PF    PG    SF    SG    All
# MVP
# 0    3971  4088  3763  4033  4048  19903
# 1      27    10    11     7     7     62
# All  3998  4098  3774  4040  4055  19965

# %% [markdown]
# Save output to image

# %%
# !pip install dataframe-image
import dataframe_image as dfi


nba_xtab_styled = nba_xtab.style.background_gradient()

dfi.export(nba_xtab_styled,'mvpXtab.png')
# Out:
# Requirement already satisfied: dataframe-image in ./hueco_mundo/lib/python3.9/site-packages (0.1.1)
# Requirement already satisfied: beautifulsoup4 in ./hueco_mundo/lib/python3.9/site-packages (from dataframe-image) (4.10.0)
# Requirement already satisfied: matplotlib>=3.1 in ./hueco_mundo/lib/python3.9/site-packages (from dataframe-image) (3.4.3)
# Requirement already satisfied: aiohttp in ./hueco_mundo/lib/python3.9/site-packages (from dataframe-image) (3.8.1)
# Requirement already satisfied: nbconvert>=5 in ./hueco_mundo/lib/python3.9/site-packages (from dataframe-image) (6.1.0)
# Requirement already satisfied: pandas>=0.24 in ./hueco_mundo/lib/python3.9/site-packages (from dataframe-image) (1.3.2)
# Requirement already satisfied: requests in ./hueco_mundo/lib/python3.9/site-packages (from dataframe-image) (2.26.0)
# Requirement already satisfied: numpy>=1.16 in ./hueco_mundo/lib/python3.9/site-packages (from matplotlib>=3.1->dataframe-image) (1.19.5)
# Requirement already satisfied: pyparsing>=2.2.1 in ./hueco_mundo/lib/python3.9/site-packages (from matplotlib>=3.1->dataframe-image) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in ./hueco_mundo/lib/python3.9/site-packages (from matplotlib>=3.1->dataframe-image) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./hueco_mundo/lib/python3.9/site-packages (from matplotlib>=3.1->dataframe-image) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./hueco_mundo/lib/python3.9/site-packages (from matplotlib>=3.1->dataframe-image) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in ./hueco_mundo/lib/python3.9/site-packages (from matplotlib>=3.1->dataframe-image) (8.3.2)
# Requirement already satisfied: jupyter-core in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (4.7.1)
# Requirement already satisfied: testpath in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (0.5.0)
# Requirement already satisfied: traitlets>=5.0 in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (5.1.0)
# Requirement already satisfied: bleach in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (0.5.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (0.8.4)
# Requirement already satisfied: nbformat>=4.4 in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (5.1.3)
# Requirement already satisfied: pygments>=2.4.1 in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (2.10.0)
# Requirement already satisfied: entrypoints>=0.2.2 in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (0.3)
# Requirement already satisfied: jinja2>=2.4 in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (3.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (1.4.3)
# Requirement already satisfied: defusedxml in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./hueco_mundo/lib/python3.9/site-packages (from nbconvert>=5->dataframe-image) (0.1.2)
# Requirement already satisfied: pytz>=2017.3 in ./hueco_mundo/lib/python3.9/site-packages (from pandas>=0.24->dataframe-image) (2021.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./hueco_mundo/lib/python3.9/site-packages (from aiohttp->dataframe-image) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in ./hueco_mundo/lib/python3.9/site-packages (from aiohttp->dataframe-image) (21.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./hueco_mundo/lib/python3.9/site-packages (from aiohttp->dataframe-image) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./hueco_mundo/lib/python3.9/site-packages (from aiohttp->dataframe-image) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in ./hueco_mundo/lib/python3.9/site-packages (from aiohttp->dataframe-image) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./hueco_mundo/lib/python3.9/site-packages (from aiohttp->dataframe-image) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./hueco_mundo/lib/python3.9/site-packages (from aiohttp->dataframe-image) (1.2.0)
# Requirement already satisfied: soupsieve>1.2 in ./hueco_mundo/lib/python3.9/site-packages (from beautifulsoup4->dataframe-image) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in ./hueco_mundo/lib/python3.9/site-packages (from requests->dataframe-image) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./hueco_mundo/lib/python3.9/site-packages (from requests->dataframe-image) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./hueco_mundo/lib/python3.9/site-packages (from requests->dataframe-image) (1.26.6)
# Requirement already satisfied: six in ./hueco_mundo/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.1->dataframe-image) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./hueco_mundo/lib/python3.9/site-packages (from jinja2>=2.4->nbconvert>=5->dataframe-image) (2.0.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in ./hueco_mundo/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (7.0.2)
# Requirement already satisfied: nest-asyncio in ./hueco_mundo/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (1.5.1)
# Requirement already satisfied: ipython-genutils in ./hueco_mundo/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert>=5->dataframe-image) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in ./hueco_mundo/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert>=5->dataframe-image) (3.2.0)
# Requirement already satisfied: webencodings in ./hueco_mundo/lib/python3.9/site-packages (from bleach->nbconvert>=5->dataframe-image) (0.5.1)
# Requirement already satisfied: packaging in ./hueco_mundo/lib/python3.9/site-packages (from bleach->nbconvert>=5->dataframe-image) (21.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./hueco_mundo/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=5->dataframe-image) (0.18.0)
# Requirement already satisfied: setuptools in ./hueco_mundo/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=5->dataframe-image) (58.0.4)
# Requirement already satisfied: tornado>=4.1 in ./hueco_mundo/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (6.1)
# Requirement already satisfied: pyzmq>=13 in ./hueco_mundo/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe-image) (22.2.1)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/christine/hueco_mundo/hueco_mundo/bin/python3 -m pip install --upgrade pip' command.
# [0213/104004.126132:INFO:headless_shell.cc(659)] Written to file /var/folders/jp/swf8p4nn0r1791yzwymqrplw0000gn/T/tmp26bbxir0/temp.png.
